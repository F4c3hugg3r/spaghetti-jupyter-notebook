# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))
plt.plot(df_clean['date'], df_clean['sensor_value'], marker='o', color='red')
plt.title('Sensor Data')
plt.xticks(rotation=45)
plt.show()

# %%
THRESHOLD = 40.0

# %%
print("using THRESHOLD: ", THRESHOLD)
df_clean = df[df['sensor_value'] <= THRESHOLD].copy()
print(f"Data cleaned. Remaining rows: {len(df_clean)}")
# Out:
# using THRESHOLD:  40.0
# Data cleaned. Remaining rows: 6

# %%
df = pd.read_csv('data.csv')
